# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
import joblib

# %%
df = pd.read_csv("/home/usama/Downloads/Clinically Validated CBC Dataset of 7,196 Samples/BDCBC7196_Hematology_Dataset.csv")

# %%
MODEL_1_FEATURES = [
    "RBC", "WBC", "PLATELETS", "Hb", "HCT",
    "MCH", "MCHC", "MCV", "RDW"
]

X1 = df[MODEL_1_FEATURES]
y1 = df["Diagnosis"]

# %%
le_m1 = LabelEncoder()
y1_enc = le_m1.fit_transform(y1)

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(
    X1, y1_enc, test_size=0.2, random_state=42, stratify=y1_enc
)

# %%
model_1 = RandomForestClassifier(
    n_estimators=300,
    max_depth=None,
    random_state=42,
    class_weight="balanced"
)

model_1.fit(X1_train, y1_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=300,
#                        random_state=42)

# %%
y1_pred = model_1.predict(X1_test)

print("Model 1 Accuracy:", accuracy_score(y1_test, y1_pred))
print(classification_report(y1_test, y1_pred, target_names=le_m1.classes_))
# Out:
# Model 1 Accuracy: 0.9048611111111111
#                            precision    recall  f1-score   support
#
# Anemia of Chronic Disease       0.90      0.91      0.91       280
#      Bacterial Infections       0.88      0.93      0.91       232
#    Beta-Thalassemia Minor       1.00      0.94      0.97        86
#         Chronic Leukemias       0.64      0.70      0.67        20
#  Infectious Mononucleosis       0.87      0.93      0.90        95
#           Iron Deficiency       1.00      1.00      1.00        46
#              Leukocytosis       0.94      0.50      0.65        34
#                Leukopenia       0.98      0.96      0.97        47
#         Microcytic Anemia       0.94      1.00      0.97        46
#                    Normal       0.70      0.86      0.77        83
#         Normocytic Anemia       0.98      0.98      0.98       253
#         Polycythemia Vera       0.50      1.00      0.67         6
# ...

# %%
joblib.dump(model_1, "model_1_core_cbc.pkl")
joblib.dump(le_m1, "label_encoder_m1.pkl")
# Out:
# ['label_encoder_m1.pkl']

# %%
MODEL_2_FEATURES = MODEL_1_FEATURES + [
    "LYMP",
    "MONO"
]
X2 = df[MODEL_2_FEATURES]
y2 = df["Diagnosis"]

# %%
le_m2 = LabelEncoder()
y2_enc = le_m2.fit_transform(y2)

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(
    X2, y2_enc, test_size=0.2, random_state=42, stratify=y2_enc
)

# %%
model_2 = RandomForestClassifier(
    n_estimators=400,
    max_depth=None,
    random_state=42,
    class_weight="balanced"
)

model_2.fit(X2_train, y2_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=400,
#                        random_state=42)

# %%
y2_pred = model_2.predict(X2_test)

print("Model 2 Accuracy:", accuracy_score(y2_test, y2_pred))
print(classification_report(y2_test, y2_pred, target_names=le_m2.classes_))
# Out:
# Model 2 Accuracy: 0.9458333333333333
#                            precision    recall  f1-score   support
#
# Anemia of Chronic Disease       0.92      0.91      0.92       280
#      Bacterial Infections       0.94      0.96      0.95       232
#    Beta-Thalassemia Minor       0.99      0.95      0.97        86
#         Chronic Leukemias       0.60      0.75      0.67        20
#  Infectious Mononucleosis       0.99      1.00      0.99        95
#           Iron Deficiency       1.00      0.98      0.99        46
#              Leukocytosis       0.88      0.85      0.87        34
#                Leukopenia       1.00      0.98      0.99        47
#         Microcytic Anemia       0.96      0.96      0.96        46
#                    Normal       0.87      0.88      0.87        83
#         Normocytic Anemia       0.98      0.98      0.98       253
#         Polycythemia Vera       0.62      0.83      0.71         6
# ...

# %%
joblib.dump(model_2, "model_2_cbc_diff.pkl")
joblib.dump(le_m2, "label_encoder_m2.pkl")
# Out:
# ['label_encoder_m2.pkl']

# %%
''' You now have 4 production files:
     These are exactly what your Flask / backend will load.
model_1_core_cbc.pkl
label_encoder_m1.pkl

model_2_cbc_diff.pkl
label_encoder_m2.pkl'''

# %%
MODEL_1_PARAMS = {
    "RBC", "WBC", "PLATELETS", "HB", "HCT",
    "MCH", "MCHC", "MCV", "RDW"
}

MODEL_2_EXTRA_PARAMS = {
    "NEUTROPHILS", "LYMPHOCYTES",
    "MONOCYTES", "EOSINOPHILS", "BASOPHILS"
}

MODEL_2_PARAMS = MODEL_1_PARAMS | MODEL_2_EXTRA_PARAMS

# %%
def present_params(input_data):
    return {
        k for k, v in input_data.items()
        if k.isupper() and v is not None and not pd.isna(v)
    }

# %%
def predict_cbc(input_data):
    present = present_params(input_data)
    results = {}

    # ---------- MODEL 1 ----------
    if MODEL_1_PARAMS.issubset(present):
        X1 = pd.DataFrame([input_data])[list(MODEL_1_PARAMS)]
        pred1 = model_1.predict(X1)[0]
        label1 = label_encoder.inverse_transform([pred1])[0]

        results["model_1"] = {
            "used": True,
            "prediction": label1
        }
    else:
        results["model_1"] = {
            "used": False,
            "prediction": None
        }

    # ---------- MODEL 2 (OPTIONAL) ----------
    if MODEL_2_PARAMS.issubset(present):
        X2 = pd.DataFrame([input_data])[list(MODEL_2_PARAMS)]
        pred2 = model_2.predict(X2)[0]
        label2 = label_encoder.inverse_transform([pred2])[0]

        results["model_2"] = {
            "used": True,
            "prediction": label2
        }
    else:
        results["model_2"] = {
            "used": False,
            "prediction": None
        }

    return results

# %%
    # example output
'''{
  "model_1": {
    "used": true,
    "prediction": "Iron Deficiency Anemia"
  },
  "model_2": {
    "used": true,
    "prediction": "Bacterial Infection with Anemia"
  }
}'''
# Out:
# '{\n  "model_1": {\n    "used": true,\n    "prediction": "Iron Deficiency Anemia"\n  },\n  "model_2": {\n    "used": true,\n    "prediction": "Bacterial Infection with Anemia"\n  }\n}'
